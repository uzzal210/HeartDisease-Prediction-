# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # UnderStanding the DataSet

# %%
df=pd.read_csv('Heart Disease.csv')

# %%
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No               3
# 1                No  20.34      No              No    Yes               0
# 2                No  26.58     Yes              No     No              20
# 3                No  24.21      No              No     No               0
# 4                No  23.71      No              No     No              28
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No               7
# 319791           No  29.84     Yes              No     No               0
# 319792           No  24.24      No              No     No               0
# 319793           No  32.81      No              No     No               0
# 319794           No  46.56      No              No     No               0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
categoricalCol = df.select_dtypes(object).columns
numericalCol = df.select_dtypes(exclude=object).columns
print('Categorical Columns: ', categoricalCol)
print('Numerical Columns: ', numericalCol)
# Out:
# Categorical Columns:  Index(['HeartDisease', 'Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking',
#        'Sex', 'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity',
#        'GenHealth', 'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')
# Numerical Columns:  Index(['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime'], dtype='object')

# %%
plt.figure(figsize=(6,5))

sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  int64
#  6   MentalHealth      319795 non-null  int64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  int64
#  15  Asthma            319795 non-null  object
# ...

# %%
df.shape
# Out:
# (319795, 18)

# %% [markdown]
# # Checking Null value

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df.HeartDisease.value_counts()
# Out:
# No     292422
# Yes     27373
# Name: HeartDisease, dtype: int64

# %% [markdown]
# # Statistical summary of the Dataset before Encoding

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %% [markdown]
# # If duplicate , then drop it

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df.shape
# Out:
# (301717, 18)

# %%
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No               3
# 1                No  20.34      No              No    Yes               0
# 2                No  26.58     Yes              No     No              20
# 3                No  24.21      No              No     No               0
# 4                No  23.71      No              No     No              28
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No               7
# 319791           No  29.84     Yes              No     No               0
# 319792           No  24.24      No              No     No               0
# 319793           No  32.81      No              No     No               0
# 319794           No  46.56      No              No     No               0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
df.HeartDisease.value_counts()
# Out:
# No     274456
# Yes     27261
# Name: HeartDisease, dtype: int64

# %%
df.BMI.skew()
# Out:
# 1.2977369892755388

# %%
df.BMI.kurt()
# Out:
# 3.690674216754272

# %%
df.BMI.std()
# Out:
# 6.468134338593027

# %%
df.BMI.var()
# Out:
# 41.83676182208626

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 18

# %%
df.columns.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 301717 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      301717 non-null  object
#  1   BMI               301717 non-null  float64
#  2   Smoking           301717 non-null  object
#  3   AlcoholDrinking   301717 non-null  object
#  4   Stroke            301717 non-null  object
#  5   PhysicalHealth    301717 non-null  int64
#  6   MentalHealth      301717 non-null  int64
#  7   DiffWalking       301717 non-null  object
#  8   Sex               301717 non-null  object
#  9   AgeCategory       301717 non-null  object
#  10  Race              301717 non-null  object
#  11  Diabetic          301717 non-null  object
#  12  PhysicalActivity  301717 non-null  object
#  13  GenHealth         301717 non-null  object
#  14  SleepTime         301717 non-null  int64
#  15  Asthma            301717 non-null  object
# ...

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  301717.000000   301717.000000  301717.000000  301717.000000
# mean       28.441970        3.572298       4.121475       7.084559
# std         6.468134        8.140656       8.128288       1.467122
# min        12.020000        0.000000       0.000000       1.000000
# 25%        24.030000        0.000000       0.000000       6.000000
# 50%        27.410000        0.000000       0.000000       7.000000
# 75%        31.650000        2.000000       4.000000       8.000000
# max        94.850000       30.000000      30.000000      24.000000

# %% [markdown]
# # Data visualization using seaborn  and matplotlib library

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.countplot(df['HeartDisease'],color='#2B00FF')
# Out:
# C:\Users\WIN\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='HeartDisease', ylabel='count'>

# %%
df.Sex.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
sns.countplot(x='Sex',hue='HeartDisease',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
df.Smoking.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
sns.countplot(x='Smoking',hue='HeartDisease',data=df)
# Out:
# <AxesSubplot:xlabel='Smoking', ylabel='count'>

# %%
df.AlcoholDrinking.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sns.countplot(x='AlcoholDrinking',hue='HeartDisease',data=df)
# Out:
# <AxesSubplot:xlabel='AlcoholDrinking', ylabel='count'>

# %%
sns.countplot(x='Stroke',hue='HeartDisease',data=df)
# Out:
# <AxesSubplot:xlabel='Stroke', ylabel='count'>

# %%
sns.countplot(x='Asthma',hue='HeartDisease',data=df)
# Out:
# <AxesSubplot:xlabel='Asthma', ylabel='count'>

# %%
sns.countplot(x='KidneyDisease',hue='HeartDisease',data=df)
# Out:
# <AxesSubplot:xlabel='KidneyDisease', ylabel='count'>

# %%
sns.countplot(x='SkinCancer',hue='HeartDisease',data=df)
# Out:
# <AxesSubplot:xlabel='SkinCancer', ylabel='count'>

# %%
df.SleepTime.max()
# Out:
# 24

# %%
df.SleepTime.min()
# Out:
# 1

# %%
sns.countplot(x='SleepTime',hue='HeartDisease',data=df)
# Out:
# <AxesSubplot:xlabel='SleepTime', ylabel='count'>

# %%
df.BMI.max()
# Out:
# 94.85

# %%
df.BMI.min()
# Out:
# 12.02

# %%
#sns.countplot(x='BMI',hue='HeartDisease',data=df) taking more time

# %%
df.Diabetic.unique()
# Out:
# array(['Yes', 'No', 'No, borderline diabetes', 'Yes (during pregnancy)'],
#       dtype=object)

# %%
sns.countplot(x='Diabetic',hue='HeartDisease',data=df)
# Out:
# <AxesSubplot:xlabel='Diabetic', ylabel='count'>

# %%
sns.countplot(x='AgeCategory',hue='HeartDisease',data=df)
# Out:
# <AxesSubplot:xlabel='AgeCategory', ylabel='count'>

# %%
sns.countplot(x='DiffWalking',hue='HeartDisease',data=df)
# Out:
# <AxesSubplot:xlabel='DiffWalking', ylabel='count'>

# %%
df.GenHealth.unique()
# Out:
# array(['Very good', 'Fair', 'Good', 'Poor', 'Excellent'], dtype=object)

# %%
sns.countplot(x='GenHealth',hue='HeartDisease',data=df)
# Out:
# <AxesSubplot:xlabel='GenHealth', ylabel='count'>

# %%
df.GenHealth.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='PhysicalActivity',hue='HeartDisease',data=df)
# Out:
# <AxesSubplot:xlabel='PhysicalActivity', ylabel='count'>

# %% [markdown]
# # EDA with PieChart

# %%
df['Sex'].value_counts().plot(kind="pie", autopct="%.2f%%",shadow=True,startangle=90)
plt.legend()
plt.show()

# %%
df['AgeCategory'].value_counts().plot(kind="pie", autopct="%.2f%%",shadow=True,startangle=90)
#plt.legend()
plt.show()

# %%
df['SleepTime'].value_counts().plot(kind="pie", autopct="%.2f%%")
#plt.legend()
plt.show()

# %%
df['GenHealth'].value_counts().plot(kind="pie", autopct="%.2f%%")
plt.legend()
plt.show()

# %%
df['MentalHealth'].value_counts().plot(kind="pie", autopct="%.2f%%")
plt.show()

# %%
df['PhysicalHealth'].value_counts().plot(kind="pie", autopct="%.2f%%")
plt.show()

# %%
df['Stroke'].value_counts().plot(kind="pie", autopct="%.2f%%")
plt.legend()
plt.show()

# %%
df['SkinCancer'].value_counts().plot(kind="pie", autopct="%.2f%%")
plt.legend()
plt.show()

# %%
df['Asthma'].value_counts().plot(kind="pie", autopct="%.2f%%")
plt.legend()
plt.show()

# %%
df['Race'].value_counts().plot(kind="pie", autopct="%.2f%%")
#plt.legend()
plt.show()

# %%
df['KidneyDisease'].value_counts().plot(kind="pie", autopct="%.2f%%")
plt.legend()
plt.show()

# %%
df['DiffWalking'].value_counts().plot(kind="pie", autopct="%.2f%%")
plt.legend()
plt.show()

# %%
df['HeartDisease'].value_counts().plot(kind="pie", autopct="%.2f%%")
plt.legend()
plt.show()

# %%
df['AlcoholDrinking'].value_counts().plot(kind="pie", autopct="%.2f%%")
plt.legend()
plt.show()

# %%
df['Smoking'].value_counts().plot(kind="pie", autopct="%.2f%%")
plt.legend()
plt.show()

# %%
df['SleepTime'].value_counts().plot(kind="bar",color='green')
plt.legend()
plt.grid()
plt.show()

# %%
df['Sex'].value_counts().plot(kind="bar",color='blue')
plt.legend()
plt.grid()
plt.show()

# %%
df['Race'].value_counts().plot(kind="bar",color='blue')
plt.legend()
plt.grid()
plt.show()

# %%
df['GenHealth'].value_counts().plot(kind="bar",color='blue')
plt.legend()
plt.grid()
plt.show()

# %%
df['AgeCategory'].value_counts().plot(kind="bar",color='blue')
plt.legend()
plt.grid()
plt.show()

# %%
df['Diabetic'].value_counts().plot(kind="bar",color='blue')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # preprocessing The DataSet

# %%
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No               3
# 1                No  20.34      No              No    Yes               0
# 2                No  26.58     Yes              No     No              20
# 3                No  24.21      No              No     No               0
# 4                No  23.71      No              No     No              28
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No               7
# 319791           No  29.84     Yes              No     No               0
# 319792           No  24.24      No              No     No               0
# 319793           No  32.81      No              No     No               0
# 319794           No  46.56      No              No     No               0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
df.shape
# Out:
# (301717, 18)

# %% [markdown]
# # Encoding The DataSet with LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
#from pandas.core.dtypes.common import is_numeric_dtype
for column in df.columns:
    if is_numeric_dtype(df[column]):
        continue
    else:
        df[column]=label.fit_transform(df[column])

# %%
df.head(15)
# Out:
#     HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0              0  16.60        1                0       0               3
# 1              0  20.34        0                0       1               0
# 2              0  26.58        1                0       0              20
# 3              0  24.21        0                0       0               0
# 4              0  23.71        0                0       0              28
# 5              1  28.87        1                0       0               6
# 6              0  21.63        0                0       0              15
# 7              0  31.64        1                0       0               5
# 8              0  26.45        0                0       0               0
# 9              0  40.69        0                0       0               0
# 10             1  34.30        1                0       0              30
# 11             0  28.71        1                0       0               0
# ...

# %% [markdown]
# # Statistical summary of the dataSet

# %%
df.describe()
# Out:
#         HeartDisease            BMI        Smoking  AlcoholDrinking  \
# count  301717.000000  301717.000000  301717.000000    301717.000000
# mean        0.090353      28.441970       0.422267         0.071527
# std         0.286687       6.468134       0.493921         0.257704
# min         0.000000      12.020000       0.000000         0.000000
# 25%         0.000000      24.030000       0.000000         0.000000
# 50%         0.000000      27.410000       0.000000         0.000000
# 75%         0.000000      31.650000       1.000000         0.000000
# max         1.000000      94.850000       1.000000         1.000000
#
#               Stroke  PhysicalHealth   MentalHealth    DiffWalking  \
# count  301717.000000   301717.000000  301717.000000  301717.000000
# mean        0.039984        3.572298       4.121475       0.147009
# std         0.195923        8.140656       8.128288       0.354115
# min         0.000000        0.000000       0.000000       0.000000
# ...

# %%
df.sum()
# Out:
# HeartDisease          27261.0
# BMI                 8581425.9
# Smoking              127405.0
# AlcoholDrinking       21581.0
# Stroke                12064.0
# PhysicalHealth      1077823.0
# MentalHealth        1243519.0
# DiffWalking           44355.0
# Sex                  142046.0
# AgeCategory         1963999.0
# Race                1317118.0
# Diabetic              95622.0
# PhysicalActivity     230412.0
# GenHealth            670179.0
# SleepTime           2137532.0
# Asthma                42651.0
# KidneyDisease         11776.0
# SkinCancer            29292.0
# dtype: float64

# %%
df.var()
# Out:
# HeartDisease         0.082190
# BMI                 41.836762
# Smoking              0.243958
# AlcoholDrinking      0.066411
# Stroke               0.038386
# PhysicalHealth      66.270288
# MentalHealth        66.069068
# DiffWalking          0.125398
# Sex                  0.249148
# AgeCategory         12.848714
# Race                 1.527243
# Diabetic             0.536368
# PhysicalActivity     0.180479
# GenHealth            2.284638
# SleepTime            2.152447
# Asthma               0.121378
# KidneyDisease        0.037507
# SkinCancer           0.087659
# dtype: float64

# %%
df.std()
# Out:
# HeartDisease        0.286687
# BMI                 6.468134
# Smoking             0.493921
# AlcoholDrinking     0.257704
# Stroke              0.195923
# PhysicalHealth      8.140656
# MentalHealth        8.128288
# DiffWalking         0.354115
# Sex                 0.499147
# AgeCategory         3.584510
# Race                1.235817
# Diabetic            0.732372
# PhysicalActivity    0.424828
# GenHealth           1.511502
# SleepTime           1.467122
# Asthma              0.348394
# KidneyDisease       0.193667
# SkinCancer          0.296073
# dtype: float64

# %%
df.mean()
# Out:
# HeartDisease         0.090353
# BMI                 28.441970
# Smoking              0.422267
# AlcoholDrinking      0.071527
# Stroke               0.039984
# PhysicalHealth       3.572298
# MentalHealth         4.121475
# DiffWalking          0.147009
# Sex                  0.470792
# AgeCategory          6.509408
# Race                 4.365409
# Diabetic             0.316926
# PhysicalActivity     0.763669
# GenHealth            2.221217
# SleepTime            7.084559
# Asthma               0.141361
# KidneyDisease        0.039030
# SkinCancer           0.097084
# dtype: float64

# %%
df.skew()
# Out:
# HeartDisease        2.857818
# BMI                 1.297737
# Smoking             0.314762
# AlcoholDrinking     3.325331
# Stroke              4.695910
# PhysicalHealth      2.501000
# MentalHealth        2.237470
# DiffWalking         1.993667
# Sex                 0.117032
# AgeCategory        -0.254694
# Race               -1.843554
# Diabetic            1.999925
# PhysicalActivity   -1.241306
# GenHealth          -0.118660
# SleepTime           0.697224
# Asthma              2.058826
# KidneyDisease       4.760482
# SkinCancer          2.721749
# dtype: float64

# %%
df.kurt()
# Out:
# HeartDisease         6.167165
# BMI                  3.690674
# Smoking             -1.900937
# AlcoholDrinking      9.057885
# Stroke              20.051700
# PhysicalHealth       4.971244
# MentalHealth         3.938538
# DiffWalking          1.974720
# Sex                 -1.986317
# AgeCategory         -1.040965
# Race                 2.337649
# Diabetic             2.324671
# PhysicalActivity    -0.459162
# GenHealth           -1.358707
# SleepTime            7.572206
# Asthma               2.238780
# KidneyDisease       20.662326
# SkinCancer           5.407954
# dtype: float64

# %%
df.max()
# Out:
# HeartDisease         1.00
# BMI                 94.85
# Smoking              1.00
# AlcoholDrinking      1.00
# Stroke               1.00
# PhysicalHealth      30.00
# MentalHealth        30.00
# DiffWalking          1.00
# Sex                  1.00
# AgeCategory         12.00
# Race                 5.00
# Diabetic             3.00
# PhysicalActivity     1.00
# GenHealth            4.00
# SleepTime           24.00
# Asthma               1.00
# KidneyDisease        1.00
# SkinCancer           1.00
# dtype: float64

# %%
df.min()
# Out:
# HeartDisease         0.00
# BMI                 12.02
# Smoking              0.00
# AlcoholDrinking      0.00
# Stroke               0.00
# PhysicalHealth       0.00
# MentalHealth         0.00
# DiffWalking          0.00
# Sex                  0.00
# AgeCategory          0.00
# Race                 0.00
# Diabetic             0.00
# PhysicalActivity     0.00
# GenHealth            0.00
# SleepTime            1.00
# Asthma               0.00
# KidneyDisease        0.00
# SkinCancer           0.00
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(df[df["HeartDisease"]==1]["Sex"], shade=True, color="red", label="Presence of Heart Disease", ax=ax)
sns.kdeplot(df[df["HeartDisease"]==0]["Sex"], shade=True, color="green", label="Absence of Heart Disease", ax=ax)

fig.suptitle("Presence of Heart Disease by Sex")
plt.grid()
ax.legend();

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(df[df["HeartDisease"]==1]["Stroke"], shade=True, color="red", label="Presence of Heart Disease", ax=ax)
sns.kdeplot(df[df["HeartDisease"]==0]["Stroke"], shade=True, color="green", label="Absence of Heart Disease", ax=ax)

fig.suptitle("Presence of Heart Disease by Stroke")
plt.grid()
ax.legend();

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(df[df["HeartDisease"]==1]["AgeCategory"], shade=True, color="red", label="Presence of Heart Disease", ax=ax)
sns.kdeplot(df[df["HeartDisease"]==0]["AgeCategory"], shade=True, color="green", label="Absence of Heart Disease", ax=ax)

fig.suptitle("Presence of Heart Disease by AgeCategory")
plt.grid()
ax.legend();

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(df[df["HeartDisease"]==1]["BMI"], shade=True, color="red", label="Presence of Heart Disease", ax=ax)
sns.kdeplot(df[df["HeartDisease"]==0]["BMI"], shade=True, color="green", label="Absence of Heart Disease", ax=ax)

fig.suptitle("Presence of Heart Disease by BMI")
plt.grid()
ax.legend();

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(df[df["HeartDisease"]==1]["AlcoholDrinking"], shade=True, color="red", label="Presence of Heart Disease", ax=ax)
sns.kdeplot(df[df["HeartDisease"]==0]["AlcoholDrinking"], shade=True, color="green", label="Absence of Heart Disease", ax=ax)

fig.suptitle("Presence of Heart Disease by AlcoholDrinking")
plt.grid()
ax.legend();

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(df[df["HeartDisease"]==1]["Race"], shade=True, color="red", label="Presence of Heart Disease", ax=ax)
sns.kdeplot(df[df["HeartDisease"]==0]["Race"], shade=True, color="green", label="Absence of Heart Disease", ax=ax)

fig.suptitle("Presence of Heart Disease by Race")
plt.grid()
ax.legend();

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(df[df["HeartDisease"]==1]["Diabetic"], shade=True, color="red", label="Presence of Heart Disease", ax=ax)
sns.kdeplot(df[df["HeartDisease"]==0]["Diabetic"], shade=True, color="green", label="Absence of Heart Disease", ax=ax)

fig.suptitle("Presence of Heart Disease by Diabetic")
plt.grid()
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(df[df["HeartDisease"]==1]["SkinCancer"], shade=True, color="red", label="Presence of Heart Disease", ax=ax)
sns.kdeplot(df[df["HeartDisease"]==0]["SkinCancer"], shade=True, color="green", label="Absence of Heart Disease", ax=ax)

fig.suptitle("Presence of Heart Disease by SkinCancer")
plt.grid()
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(df[df["HeartDisease"]==1]["Asthma"], shade=True, color="red", label="Presence of Heart Disease", ax=ax)
sns.kdeplot(df[df["HeartDisease"]==0]["Asthma"], shade=True, color="green", label="Absence of Heart Disease", ax=ax)

fig.suptitle("Presence of Heart Disease by Asthma")
plt.grid()
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(df[df["HeartDisease"]==1]["KidneyDisease"], shade=True, color="red", label="Presence of Heart Disease", ax=ax)
sns.kdeplot(df[df["HeartDisease"]==0]["KidneyDisease"], shade=True, color="green", label="Absence of Heart Disease", ax=ax)

fig.suptitle("Presence of Heart Disease by KidneyDisease")
plt.grid()
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(df[df["HeartDisease"]==1]["GenHealth"], shade=True, color="red", label="Presence of Heart Disease", ax=ax)
sns.kdeplot(df[df["HeartDisease"]==0]["GenHealth"], shade=True, color="green", label="Absence of Heart Disease", ax=ax)

fig.suptitle("Presence of Heart Disease by GenHealth")
plt.grid()
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(df[df["HeartDisease"]==1]["MentalHealth"], shade=True, color="red", label="Presence of Heart Disease", ax=ax)
sns.kdeplot(df[df["HeartDisease"]==0]["MentalHealth"], shade=True, color="green", label="Absence of Heart Disease", ax=ax)

fig.suptitle("Presence of Heart Disease by MentalHealth")
plt.grid()
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(df[df["HeartDisease"]==1]["PhysicalHealth"], shade=True, color="red", label="Presence of Heart Disease", ax=ax)
sns.kdeplot(df[df["HeartDisease"]==0]["PhysicalHealth"], shade=True, color="green", label="Absence of Heart Disease", ax=ax)

fig.suptitle("Presence of Heart Disease by PhysicalHealth")
plt.grid()
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(df[df["HeartDisease"]==1]["PhysicalActivity"], shade=True, color="red", label="Presence of Heart Disease", ax=ax)
sns.kdeplot(df[df["HeartDisease"]==0]["PhysicalActivity"], shade=True, color="green", label="Absence of Heart Disease", ax=ax)

fig.suptitle("Presence of Heart Disease by PhysicalActivity")
plt.grid()
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.kdeplot(df[df["HeartDisease"]==1]["DiffWalking"], shade=True, color="red", label="Presence of Heart Disease", ax=ax)
sns.kdeplot(df[df["HeartDisease"]==0]["DiffWalking"], shade=True, color="green", label="Absence of Heart Disease", ax=ax)

fig.suptitle("Presence of Heart Disease by DiffWalking")
plt.grid()
ax.legend()

# %% [markdown]
# # Create the correlation matrix without Feature Engineering

# %%
plt.figure(figsize=(15,15))

sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Seperating x and y

# %%
x=df.drop('HeartDisease',axis=1)
y=df['HeartDisease']

# %%
x1=x2=x
x
# Out:
#           BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0       16.60        1                0       0               3            30
# 1       20.34        0                0       1               0             0
# 2       26.58        1                0       0              20            30
# 3       24.21        0                0       0               0             0
# 4       23.71        0                0       0              28             0
# ...       ...      ...              ...     ...             ...           ...
# 319790  27.41        1                0       0               7             0
# 319791  29.84        1                0       0               0             0
# 319792  24.24        0                0       0               0             0
# 319793  32.81        0                0       0               0             0
# 319794  46.56        0                0       0               0             0
#
# ...

# %%
x.shape
# Out:
# (301717, 17)

# %%
y1=y2=y
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 319790    1
# 319791    0
# 319792    0
# 319793    0
# 319794    0
# Name: HeartDisease, Length: 301717, dtype: int32

# %%
y.shape
# Out:
# (301717,)

# %%
'''sns.pairplot(df[['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
       'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
       'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
       'Asthma', 'KidneyDisease', 'SkinCancer']])'''
# Out:
# "sns.pairplot(df[['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',\n       'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',\n       'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',\n       'Asthma', 'KidneyDisease', 'SkinCancer']])"

# %%
y1
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 319790    1
# 319791    0
# 319792    0
# 319793    0
# 319794    0
# Name: HeartDisease, Length: 301717, dtype: int32

# %% [markdown]
# # Feature Engineering for selecting best Feature

# %% [markdown]
# # Extra Tree Classifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
extra=ExtraTreesClassifier()

# %%
extra.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
feature_importance=extra.feature_importances_
feature_importance
# Out:
# array([0.34268759, 0.01312387, 0.0073016 , 0.02843347, 0.08080846,
#        0.07687608, 0.02305657, 0.01661442, 0.10401823, 0.03786848,
#        0.02658844, 0.01774224, 0.05615351, 0.12676402, 0.01599321,
#        0.01348003, 0.01248979])

# %%
imp=pd.DataFrame(feature_importance,columns=['Gain_Score'])

# %%
imp.head()
# Out:
#    Gain_Score
# 0    0.342688
# 1    0.013124
# 2    0.007302
# 3    0.028433
# 4    0.080808

# %%
x.columns
# Out:
# Index(['BMI', 'Smoking', 'AlcoholDrinking', 'Stroke', 'PhysicalHealth',
#        'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic',
#        'PhysicalActivity', 'GenHealth', 'SleepTime', 'Asthma', 'KidneyDisease',
#        'SkinCancer'],
#       dtype='object')

# %%
cols=pd.DataFrame(x.columns,columns=['Feature_Names'])
cols
# Out:
#        Feature_Names
# 0                BMI
# 1            Smoking
# 2    AlcoholDrinking
# 3             Stroke
# 4     PhysicalHealth
# 5       MentalHealth
# 6        DiffWalking
# 7                Sex
# 8        AgeCategory
# 9               Race
# 10          Diabetic
# 11  PhysicalActivity
# 12         GenHealth
# 13         SleepTime
# 14            Asthma
# 15     KidneyDisease
# 16        SkinCancer

# %% [markdown]
# # Column concatenation

# %%
gains=pd.concat([cols,imp],axis=1)
gains
# Out:
#        Feature_Names  Gain_Score
# 0                BMI    0.342688
# 1            Smoking    0.013124
# 2    AlcoholDrinking    0.007302
# 3             Stroke    0.028433
# 4     PhysicalHealth    0.080808
# 5       MentalHealth    0.076876
# 6        DiffWalking    0.023057
# 7                Sex    0.016614
# 8        AgeCategory    0.104018
# 9               Race    0.037868
# 10          Diabetic    0.026588
# 11  PhysicalActivity    0.017742
# 12         GenHealth    0.056154
# 13         SleepTime    0.126764
# 14            Asthma    0.015993
# 15     KidneyDisease    0.013480
# 16        SkinCancer    0.012490

# %%
newx=gains.nlargest(16,'Gain_Score') #to see largest feature
newx
# Out:
#        Feature_Names  Gain_Score
# 0                BMI    0.342688
# 13         SleepTime    0.126764
# 8        AgeCategory    0.104018
# 4     PhysicalHealth    0.080808
# 5       MentalHealth    0.076876
# 12         GenHealth    0.056154
# 9               Race    0.037868
# 3             Stroke    0.028433
# 10          Diabetic    0.026588
# 6        DiffWalking    0.023057
# 11  PhysicalActivity    0.017742
# 7                Sex    0.016614
# 14            Asthma    0.015993
# 15     KidneyDisease    0.013480
# 1            Smoking    0.013124
# 16        SkinCancer    0.012490

# %%
newx.plot(kind='bar',color='green')
# Out:
# <AxesSubplot:>

# %%
features=pd.Series(extra.feature_importances_,index=x.columns)
plt.figure(figsize=(10,6))
features.nlargest(16).plot(kind='bar',color='green')
plt.savefig('ETC.png')

# %% [markdown]
# # Correlation Matrix

# %%
x.corr()
x.columns
feature_names=x.columns
colname=x.corr().index
plt.figure(figsize=(15,15))
sns.heatmap(df[colname].corr(),annot=True)
plt.savefig('heatmap2.png')

# %% [markdown]
# # Select K Best

# %%
x.head()
# Out:
#      BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0  16.60        1                0       0               3            30
# 1  20.34        0                0       1               0             0
# 2  26.58        1                0       0              20            30
# 3  24.21        0                0       0               0             0
# 4  23.71        0                0       0              28             0
#
#    DiffWalking  Sex  AgeCategory  Race  Diabetic  PhysicalActivity  GenHealth  \
# 0            0    0            7     5         2                 1          4
# 1            0    0           12     5         0                 1          4
# 2            0    1            9     5         2                 1          1
# 3            0    0           11     5         0                 0          2
# 4            1    0            4     5         0                 1          4
#
#    SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
from sklearn.feature_selection import SelectKBest,f_classif,chi2
model1=SelectKBest(score_func=f_classif)#Based on ANNOVA

# %%
feature_score=model1.fit(x,y)

# %%
feature_score.scores_
# Out:
# array([  675.39004217,  3332.70594864,   397.84081359, 11883.65392597,
#         8468.84943852,   132.01269561, 12107.52198864,  1680.96961257,
#        18320.37822661,   551.63769651,  8306.39253374,  2666.49347211,
#           45.05769891,    35.41591461,   386.83499119,  6269.07272683,
#         2499.55567097])

# %%
cols2=pd.DataFrame(feature_score.scores_,columns=['Feature_Score'])
cols2
# Out:
#     Feature_Score
# 0      675.390042
# 1     3332.705949
# 2      397.840814
# 3    11883.653926
# 4     8468.849439
# 5      132.012696
# 6    12107.521989
# 7     1680.969613
# 8    18320.378227
# 9      551.637697
# 10    8306.392534
# 11    2666.493472
# 12      45.057699
# 13      35.415915
# 14     386.834991
# 15    6269.072727
# 16    2499.555671

# %%
x.columns
# Out:
# Index(['BMI', 'Smoking', 'AlcoholDrinking', 'Stroke', 'PhysicalHealth',
#        'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic',
#        'PhysicalActivity', 'GenHealth', 'SleepTime', 'Asthma', 'KidneyDisease',
#        'SkinCancer'],
#       dtype='object')

# %%
col2=pd.DataFrame(x.columns,columns=['Features_Names'])
col2
# Out:
#       Features_Names
# 0                BMI
# 1            Smoking
# 2    AlcoholDrinking
# 3             Stroke
# 4     PhysicalHealth
# 5       MentalHealth
# 6        DiffWalking
# 7                Sex
# 8        AgeCategory
# 9               Race
# 10          Diabetic
# 11  PhysicalActivity
# 12         GenHealth
# 13         SleepTime
# 14            Asthma
# 15     KidneyDisease
# 16        SkinCancer

# %% [markdown]
# # Concatenation

# %%
scores=pd.concat([col2,cols2],axis=1)
scores
# Out:
#       Features_Names  Feature_Score
# 0                BMI     675.390042
# 1            Smoking    3332.705949
# 2    AlcoholDrinking     397.840814
# 3             Stroke   11883.653926
# 4     PhysicalHealth    8468.849439
# 5       MentalHealth     132.012696
# 6        DiffWalking   12107.521989
# 7                Sex    1680.969613
# 8        AgeCategory   18320.378227
# 9               Race     551.637697
# 10          Diabetic    8306.392534
# 11  PhysicalActivity    2666.493472
# 12         GenHealth      45.057699
# 13         SleepTime      35.415915
# 14            Asthma     386.834991
# 15     KidneyDisease    6269.072727
# 16        SkinCancer    2499.555671

# %%
scores.nlargest(16,'Feature_Score')
# Out:
#       Features_Names  Feature_Score
# 8        AgeCategory   18320.378227
# 6        DiffWalking   12107.521989
# 3             Stroke   11883.653926
# 4     PhysicalHealth    8468.849439
# 10          Diabetic    8306.392534
# 15     KidneyDisease    6269.072727
# 1            Smoking    3332.705949
# 11  PhysicalActivity    2666.493472
# 16        SkinCancer    2499.555671
# 7                Sex    1680.969613
# 0                BMI     675.390042
# 9               Race     551.637697
# 2    AlcoholDrinking     397.840814
# 14            Asthma     386.834991
# 5       MentalHealth     132.012696
# 12         GenHealth      45.057699

# %%
len(x.columns)
# Out:
# 17

# %%
newx=scores.nlargest(16,'Feature_Score')
newx
# Out:
#       Features_Names  Feature_Score
# 8        AgeCategory   18320.378227
# 6        DiffWalking   12107.521989
# 3             Stroke   11883.653926
# 4     PhysicalHealth    8468.849439
# 10          Diabetic    8306.392534
# 15     KidneyDisease    6269.072727
# 1            Smoking    3332.705949
# 11  PhysicalActivity    2666.493472
# 16        SkinCancer    2499.555671
# 7                Sex    1680.969613
# 0                BMI     675.390042
# 9               Race     551.637697
# 2    AlcoholDrinking     397.840814
# 14            Asthma     386.834991
# 5       MentalHealth     132.012696
# 12         GenHealth      45.057699

# %%
newx.plot(kind='bar',color='green')
plt.figure(figsize=(12,12))

# %% [markdown]
# # Imbalanced Data Handling

# %%
df.HeartDisease.value_counts()
# Out:
# 0    274456
# 1     27261
# Name: HeartDisease, dtype: int64

# %%
not_HeartDisease=(274456/(274456+27261))*100
HeartDisease=(27261/(274456+27261))*100

# %%
print('No HeartDisease {} percent of the total people'.format(not_HeartDisease))
# Out:
# No HeartDisease 90.96471196518591 percent of the total people

# %%
print('HeartDisease {} percent of the total people'.format(HeartDisease))
# Out:
# HeartDisease 9.03528803481408 percent of the total people

# %%
HeartDisease_no=df[df['HeartDisease']==0]
HeartDisease_yes=df[df['HeartDisease']==1]

# %%
HeartDisease_no.shape
# Out:
# (274456, 18)

# %%
HeartDisease_yes.shape
# Out:
# (27261, 18)

# %% [markdown]
# # So we have to balance our dataset . Now applying  Random over sampling techniques

# %% [markdown]
# # Over sampling

# %%
from imblearn.over_sampling import RandomOverSampler
random_over_sampler = RandomOverSampler(random_state =100)

# %%
x_new,y_new=random_over_sampler.fit_resample(x,y)

# %%
x1_new=x2_new=x3_new=x4_new=x5_new=x6_new=x7_new=x8_new=x9_new=x_new

# %%
x_new
# Out:
#           BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0       16.60        1                0       0               3            30
# 1       20.34        0                0       1               0             0
# 2       26.58        1                0       0              20            30
# 3       24.21        0                0       0               0             0
# 4       23.71        0                0       0              28             0
# ...       ...      ...              ...     ...             ...           ...
# 548907  35.43        0                0       0               0             0
# 548908  23.01        1                0       0               0            20
# 548909  30.80        0                0       0               0             0
# 548910  44.63        0                0       0               0             7
# 548911  30.90        0                0       0               0            10
#
# ...

# %%
x4_new
# Out:
#           BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0       16.60        1                0       0               3            30
# 1       20.34        0                0       1               0             0
# 2       26.58        1                0       0              20            30
# 3       24.21        0                0       0               0             0
# 4       23.71        0                0       0              28             0
# ...       ...      ...              ...     ...             ...           ...
# 548907  35.43        0                0       0               0             0
# 548908  23.01        1                0       0               0            20
# 548909  30.80        0                0       0               0             0
# 548910  44.63        0                0       0               0             7
# 548911  30.90        0                0       0               0            10
#
# ...

# %%
y1_new=y2_new=y3_new=y4_new=y5_new=y6_new=y7_new=y8_new=y9_new=y_new

# %%
y_new
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 548907    1
# 548908    1
# 548909    1
# 548910    1
# 548911    1
# Name: HeartDisease, Length: 548912, dtype: int32

# %%
y5_new
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 548907    1
# 548908    1
# 548909    1
# 548910    1
# 548911    1
# Name: HeartDisease, Length: 548912, dtype: int32

# %%
x_new.shape
# Out:
# (548912, 17)

# %%
y_new.shape
# Out:
# (548912,)

# %%
y_new.value_counts()
# Out:
# 0    274456
# 1    274456
# Name: HeartDisease, dtype: int64

# %%
x_new
# Out:
#           BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0       16.60        1                0       0               3            30
# 1       20.34        0                0       1               0             0
# 2       26.58        1                0       0              20            30
# 3       24.21        0                0       0               0             0
# 4       23.71        0                0       0              28             0
# ...       ...      ...              ...     ...             ...           ...
# 548907  35.43        0                0       0               0             0
# 548908  23.01        1                0       0               0            20
# 548909  30.80        0                0       0               0             0
# 548910  44.63        0                0       0               0             7
# 548911  30.90        0                0       0               0            10
#
# ...

# %%
y_new
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 548907    1
# 548908    1
# 548909    1
# 548910    1
# 548911    1
# Name: HeartDisease, Length: 548912, dtype: int32

# %% [markdown]
# # All about DecisionTreeClassifier with Hold out cross validation ,KFold cross validation,stratified k fold cross validation

# %% [markdown]
# # Hold out Cross validation for over sampling

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split

# %%
over_xtrain,over_xtest,over_ytrain,over_ytest = train_test_split(x_new,y_new,test_size = 0.30 ,random_state =42)
dtc.fit(over_xtrain,over_ytrain)
# Out:
# DecisionTreeClassifier()

# %%
OverSampleing_dataset_accuracy = dtc.score(over_xtest,over_ytest)

OverSampleing_dataset_accuracy
# Out:
# 0.9473565954552631

# %% [markdown]
# # KFold Cross Validation for Over sampling

# %%
from sklearn.model_selection import KFold, cross_val_score

kfold = KFold(n_splits = 10)

# %%
OverSampleingDataset_kfold_result = cross_val_score(dtc,x_new,y_new,cv = kfold)

OverSampleingDataset_kfold_result
# Out:
# array([0.91541573, 0.91488742, 0.91570567, 0.91940391, 0.91816509,
#        0.9594469 , 1.        , 1.        , 1.        , 1.        ])

# %%
OverSampleingDataset_kfold_result.min()
# Out:
# 0.9148874152882023

# %%
OverSampleingDataset_kfold_result.max()
# Out:
# 1.0

# %%
OverSampleingDataset_kfold_result.mean()
# Out:
# 0.9543024716198636

# %% [markdown]
# # StratiFied KFold cross validation for Over sampling

# %%
from sklearn.model_selection import StratifiedKFold

Stf_Kfold = StratifiedKFold(n_splits = 10)

# %%
OverSampleingDataset_Sf_kfold_result = cross_val_score(dtc,x_new,y_new,cv = Stf_Kfold)

OverSampleingDataset_Sf_kfold_result
# Out:
# array([0.95651461, 0.95511186, 0.95685996, 0.95684174, 0.9575158 ,
#        0.95449163, 0.9617788 , 0.95294311, 0.95880928, 0.95675065])

# %%
OverSampleingDataset_Sf_kfold_result.min()
# Out:
# 0.9529431054271192

# %%
OverSampleingDataset_Sf_kfold_result.max()
# Out:
# 0.9617787979814542

# %%
OverSampleingDataset_Sf_kfold_result.mean()
# Out:
# 0.9567617430426363

# %% [markdown]
# # Hence we see that StratiFied KFold C.V and Over sampling give the best accuracy

# %% [markdown]
# # Now from over sampling ,We draw DecisionTreeModel and calculate all confusion matrix performance

# %%
dtc.fit(over_xtrain,over_ytrain)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Model Evaluating Performance of confusion matrix

# %%
pred_y=dtc.predict(over_xtest)#Predicted Class 
pred_y
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
over_ytest
# Out:
# 374936    1
# 319916    1
# 56188     0
# 444156    1
# 170814    0
#          ..
# 285161    0
# 217312    1
# 353792    1
# 318432    1
# 216193    0
# Name: HeartDisease, Length: 164674, dtype: int32

# %%
np.array(over_ytest) #actual class/y
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix,plot_roc_curve

# %%
print(classification_report(over_ytest,pred_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.94     82143
#            1       0.91      1.00      0.95     82531
#
#     accuracy                           0.95    164674
#    macro avg       0.95      0.95      0.95    164674
# weighted avg       0.95      0.95      0.95    164674

# %%
cm=confusion_matrix(over_ytest,pred_y)
cm
# Out:
# array([[73595,  8548],
#        [   59, 82472]], dtype=int64)

# %% [markdown]
# # Visualization with heatmap  performance of confussion matrix

# %%
sns.heatmap(cm,annot=True)
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
# Out:
# Text(33.0, 0.5, 'Actual Values')

# %%
tp,fn,fp,tn=confusion_matrix(over_ytest,pred_y).reshape(-1)

# %%
tp
# Out:
# 73595

# %%
fn
# Out:
# 8548

# %%
fp
# Out:
# 59

# %%
tn
# Out:
# 82472

# %%
(tp+tn)
# Out:
# 156067

# %% [markdown]
# # Accuracy

# %%
(tp+tn)/(tp+fn+fp+tn)
# Out:
# 0.9477330969066154

# %% [markdown]
# # Precision or positive predicted value(PPV)

# %%
ppv = tp/(tp+fp)
print(ppv)
# Out:
# 0.9991989572867733

# %% [markdown]
# # True positive rate(TPR),Sensitivity,Recall,Hit Rate

# %%
trp = tp/(tp+fn)
print(trp)
# Out:
# 0.8959375722824829

# %% [markdown]
# # False positive rate(1-Specificity)

# %%
fpr = fp/(fp+tn)
print(fpr)
# Out:
# 0.0007148828924888829

# %% [markdown]
# # F1-Score,Harmonic Mean

# %%
f1_score = (2*ppv*trp)/(ppv+trp)
print(f1_score)
# Out:
# 0.9447550337939755

# %% [markdown]
# # True nagative Rate(TNR),Specificity,Selectivity

# %%
tnr = tn/(tn+fp)
print(tnr)
# Out:
# 0.9992851171075111

# %% [markdown]
# # Critical sucvcess index(CSI),Threat Score(TS)

# %%
csi = tp/(tp+fn+fp)
print(csi)
# Out:
# 0.8952945183815479

# %% [markdown]
# # False discovery Rate(FDR)

# %%
fdr = fp/(tp+fp)
print(fdr)
# Out:
# 0.0008010427132267087

# %% [markdown]
# # Roc and Auc curve for decision tree classifier

# %%
plot_roc_curve(dtc,over_xtest,over_ytest,color='red')
plt.plot([0,1],[0,1])
# Out:
# C:\Users\WIN\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # Now Optimizing DecisionTreeClassifier Algorithm

# %% [markdown]
# # Tuning DecisionTreeClassifier using Randomized Search CV

# %%
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # Assign Parameters

# %%
splitter=['best','random']
criterion=['gini','entropy']
max_features=['auto','sqrt','log2']
max_depth=np.random.randint(1,12,20)
min_samples_split=np.random.randint(1,12,15)
max_leaf_nodes=np.random.randint(1,12,15)


parameters={
    'splitter':splitter,
    'criterion':criterion,
    'max_features':max_features,
    'max_depth':max_depth,
    'min_samples_split':min_samples_split,
    'max_leaf_nodes':max_leaf_nodes
       
}

# %%
print(parameters)
# Out:
# {'splitter': ['best', 'random'], 'criterion': ['gini', 'entropy'], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': array([ 5,  2,  6,  7,  4,  6,  8,  1,  6, 10, 10,  7,  9,  4,  8,  8,  8,
#         8,  3,  6]), 'min_samples_split': array([ 9,  8, 10,  3,  5,  2,  7,  8,  9,  5, 10,  8, 11,  5, 11]), 'max_leaf_nodes': array([ 7,  7,  9,  8, 10, 10,  3,  1, 11,  9,  7,  5, 10,  7,  9])}

# %%
import warnings
warnings.filterwarnings('ignore')
r=RandomizedSearchCV(dtc,parameters,n_iter=200,cv=3)
r.fit(over_xtrain,over_ytrain)
# Out:
# RandomizedSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_iter=200,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': array([ 5,  2,  6,  7,  4,  6,  8,  1,  6, 10, 10,  7,  9,  4,  8,  8,  8,
#         8,  3,  6]),
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'max_leaf_nodes': array([ 7,  7,  9,  8, 10, 10,  3,  1, 11,  9,  7,  5, 10,  7,  9]),
#                                         'min_samples_split': array([ 9,  8, 10,  3,  5,  2,  7,  8,  9,  5, 10,  8, 11,  5, 11]),
#                                         'splitter': ['best', 'random']})

# %%
r.cv_results_
# Out:
# {'mean_fit_time': array([0.4193364 , 0.42711639, 0.42711719, 0.41149338, 0.46878839,
#         0.47399537, 0.17709835, 0.34419982, 0.48284038, 0.46874984,
#         0.47405799, 0.56775371, 0.34377845, 0.35939876, 0.20835018,
#         0.31253513, 0.28648218, 0.25522661, 0.20835121, 0.35940576,
#         0.41669599, 0.39065107, 0.18230518, 0.42020941, 0.35940138,
#         0.33340716, 0.4592828 , 0.30730939, 0.39586218, 0.41669981,
#         0.41149147, 0.54892278, 0.39739799, 0.33008289, 0.50003862,
#         0.41669806, 0.45836822, 0.45325947, 0.43232536, 0.32815146,
#         0.31773225, 0.16668042, 0.40628076, 0.34898583, 0.364856  ,
#         0.6250488 , 0.41149298, 0.31252797, 0.41670028, 0.58337649,
#         0.3333594 , 0.33203348, 0.37503099, 0.2098244 , 0.44274481,
#         0.59149456, 0.51825182, 0.50658067, 0.41149076, 0.54981105,
#         0.59575868, 0.41483227, 0.39999906, 0.44800822, 0.59986655,
#         0.3601613 , 0.51052443, 0.36108375, 0.35419432, 0.50524592,
# ...

# %%
result=pd.DataFrame(r.cv_results_)
result
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.419336      0.054273         0.083344    1.472538e-02
# 1         0.427116      0.007367         0.072923    7.366033e-03
# 2         0.427117      0.036828         0.062503    4.785560e-06
# 3         0.411493      0.007367         0.057293    7.365583e-03
# 4         0.468788      0.033754         0.062503    2.480266e-06
# ..             ...           ...              ...             ...
# 195       0.307318      0.007366         0.052087    7.366932e-03
# 196       0.359403      0.012756         0.052089    7.366595e-03
# 197       0.416698      0.029466         0.062506    9.798072e-07
# 198       0.302108      0.007367         0.046878    9.798072e-07
# 199       0.145847      0.007365         0.000000    0.000000e+00
#
#     param_splitter param_min_samples_split param_max_leaf_nodes  \
# 0           random                       7                    7
# ...

# %%
r.best_score_
# Out:
# 0.7248268069205809

# %%
new_r=r.best_estimator_
new_r
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=8, max_features='auto',
#                        max_leaf_nodes=11, min_samples_split=3)

# %%
new_r.fit(over_xtrain,over_ytrain)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=8, max_features='auto',
#                        max_leaf_nodes=11, min_samples_split=3)

# %%
new_r.score(over_xtest,over_ytest)
# Out:
# 0.6716907344207343
